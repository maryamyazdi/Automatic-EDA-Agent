# %%
from pathlib import Path
import sys
import warnings

warnings.filterwarnings('ignore')

if str(Path.cwd().parent) not in sys.path:
    sys.path.append(str(Path.cwd().parent))

# %%
from src import TabularBot

# %% [markdown]
# ### test_case A:

# %%
bot = TabularBot(path='./data/Impact of facebook addiction on narcissistic behavior and self-esteem among students.xlsx')

query = """
I have data about the addiction to social media and its relation with narcissism, self-steem, gender, etc.
I want to know how social media addiction affects different factors and vise-versa. I want data analysis, visualisations and
anything which could give me more insight about this.
"""

bot.process_query(user_query=query)
# Out:
# [tabular bot] data loaded!
# [tabular bot] Processing the query...
#
# #####
#  - Task 1/8: Perform a descriptive statistical analysis on the dataframe. This includes finding the mean, median, mode, standard deviation, and range for each of the numerical columns: 'Participant', 'Facebook Addiction Score', 'Narcissism Score', and 'Self-Esteem Score'. Also, provide the count of unique values for each of the categorical columns: 'Gender' and 'Family Type'.
#  - Tool: DataAnalyzer
# - Statistical Analysis:
#        Participant  Facebook Addiction Score  Narcissism Score  Self-Esteem Score
# count    40.000000                 40.000000          40.00000          40.000000
# mean     20.500000                 15.975000          24.85000          27.400000
# std      11.690452                  2.130216           3.46817           3.144389
# min       1.000000                 12.000000          19.00000          22.000000
# ...

# %% [markdown]
# ### test_case B:

# %%
bot = TabularBot(path='./data/survey lung cancer.csv')

query = """
I've got the dataset of different symptoms of lung cancer. For the first column (Gender), 'M' stands for male and 'F' for female respectively. The 'Age' column shows the age of the patient. And for the remaining columns, '1'=NO and '2'=YES.
On this dataset, I want to know what is the most common determinative symptom of lung cancer, how the cancer is related to the age and other potential hidden patterns. Generally, I want to get a better understanding of this dataset using different data analyses and visalizations.
"""

bot.process_query(user_query=query)
# Out:
# [tabular bot] data loaded!
# [tabular bot] Processing the query...
#
# #####
#  - Task 1/12: Convert the 'GENDER' column from object type to categorical type with 'M' as 'Male' and 'F' as 'Female'.
#  - Tool: DataAnalyzer
# - Statistical Analysis:
# GENDER                   category
# AGE                         int64
# SMOKING                     int64
# YELLOW_FINGERS              int64
# ANXIETY                     int64
# PEER_PRESSURE               int64
# CHRONIC DISEASE             int64
# FATIGUE                     int64
# ALLERGY                     int64
# WHEEZING                    int64
# ALCOHOL CONSUMING           int64
# COUGHING                    int64
# SHORTNESS OF BREATH         int64
# SWALLOWING DIFFICULTY       int64
# CHEST PAIN                  int64
# LUNG_CANCER                object
# dtype: object
#
#
# - Interpretation:
# ...

# %% [markdown]
# ### test_case C:

# %%
bot = TabularBot(path='./data/flights.csv')

query = """
The dataset contains information about the flights of an airport. This dataset includes information such as departure and arrival time,
delays, flight company, flight number, flight origin and destination, flight duration, distance, hour and minute of flight,
and exact date and time of flight.
This data can be used in management analysis and strategies and provide useful information about the performance of flights
and placement companies.
I want you to use this data in order to extract insights on the quality of service that companies and the airports provide,
and extract insight on how to improve the service quality.
I also would like a compariosn between the different companies and airports regarding the service quality.
"""

bot.process_query(user_query=query)
# Out:
# [tabular bot] data loaded!
# [tabular bot] Processing the query...
#
# #####
#  - Task 1/11: Perform an initial data analysis on the dataset. This includes checking for missing values, checking the data types of each column, and getting a general sense of the data distribution.
#  - Tool: DataAnalyzer
# - Statistical Analysis:
# id                   0
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# name                 0
# dtype: int64
# id                  int64
# year                int64
# month               int64
# day                 int64
# ...
